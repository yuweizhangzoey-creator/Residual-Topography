# %%
import geopandas as gpd
import rioxarray
import xarray as xr
gdf = gpd.read_file('BABs_polygens.geojson')




rt=xr.open_dataset("netcdf/RT_LithoRef18_Richards.nc")
Residual_anomaly=rt['z']
Residual_anomaly = Residual_anomaly.rio.set_spatial_dims(x_dim='lon', y_dim='lat', inplace=False)
Residual_anomaly = Residual_anomaly.rio.write_crs("EPSG:4326")


means = []
stds = []

for idx, poly in gdf.iterrows():
    clipped = Residual_anomaly.rio.clip([poly.geometry], all_touched=True)
    mean_depth = float(clipped.mean()) 
    std_depth  = float(clipped.std()) 

    means.append(mean_depth)
    stds.append(std_depth)

gdf["Residual_anomaly"] = means
gdf["Residual_anomaly_std"] = stds
gdf = gdf.sort_values(by='id')

print(gdf[["id","Residual_anomaly","Residual_anomaly_std"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/micromamba/envs/gplately/lib/python3.13/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/micromamba/envs/gplately/lib/python3.13/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/yzha0335/Documents/2026/paper1/Repository/netcdf/RT_LithoRef18_Richards.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '5d95cea5-1174-4b60-896e-2c9926342916']
#
# During handling of the above exception, another exception occurred:
#
# ...
